# %%
# Imports libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#  Load the dataset
ds = pd.read_csv('House Price Prediction Dataset.csv')
ds
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %%
#  Check for duplicates
ds.duplicated().sum()
ds.drop_duplicates(inplace=True)

# %%
# 5. Check for missing values 
print( ds.isnull().sum())
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
# Handle outliers
ds = ds[ds['Area'].between(400, 10000)]
ds = ds[ds['Price'].between(20000, 2000000)]
ds = ds[ds['Bedrooms'].between(1, 10)]
ds = ds[ds['Bathrooms'].between(1, 10)]
ds = ds[ds['Floors'].between(1, 5)]
ds = ds[ds['YearBuilt'] >= 1930]

# %%
# check
ds.info()
ds.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1504 entries, 0 to 1998
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         1504 non-null   int64
#  1   Area       1504 non-null   int64
#  2   Bedrooms   1504 non-null   int64
#  3   Bathrooms  1504 non-null   int64
#  4   Floors     1504 non-null   int64
#  5   YearBuilt  1504 non-null   int64
#  6   Location   1504 non-null   object
#  7   Condition  1504 non-null   object
#  8   Garage     1504 non-null   object
#  9   Price      1504 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 129.2+ KB
#                 Id         Area     Bedrooms    Bathrooms       Floors  \
# count  1504.000000  1504.000000  1504.000000  1504.000000  1504.000000
# mean   1005.656915  2771.878989     2.994681     2.543883     2.005319
# std     577.529696  1294.265315     1.421711     1.112771     0.803335
# ...

# %%
# to save file
ds.to_csv('Cleaned_House_Price_Data.csv', index=False)
